# %%
import pandas as pd
import google.generativeai as genai
import matplotlib.pyplot as plt
from io import StringIO

genai.configure(api_key="AIzaSyBxwEful227H26kqk64Hj_y9TkGkmF23uc")

generation_config = {
  "temperature": 1.5,
}

model = genai.GenerativeModel(
  model_name="gemini-2.0-flash",
  generation_config=generation_config,
)

chat_session = model.start_chat()

response = chat_session.send_message("Generate data points of an artificial stock price chart for 1000 days (1000 data points). The price must have 2 numbers from the decimal point. You must return only the Y value in CSV format without extra words.")

print(response.text)
df = pd.read_csv(StringIO(response.text))
plt.plot(df)
plt.xlabel("Days")
plt.ylabel("Stock Price")
plt.title("Artificial Stock Price Chart")
plt.show()
# Out:
# ```csv
# 100.00
# 100.25
# 100.50
# 100.75
# 101.00
# 101.25
# 101.50
# 101.75
# 102.00
# 102.25
# 102.50
# 102.75
# 103.00
# 103.25
# 103.50
# 103.75
# 104.00
# 104.25
# 104.50
# 104.75
# 105.00
# 105.25
# 105.50
# 105.75
# 106.00
# 106.25
# 106.50
# 106.75
# 107.00
# 107.25
# 107.50
# 107.75
# 108.00
# 108.25
# 108.50
# 108.75
# 109.00
# 109.25
# 109.50
# 109.75
# 110.00
# 110.25
# 110.50
# 110.75
# 111.00
# 111.25
# 111.50
# 111.75
# 112.00
# 112.25
# 112.50
# 112.75
# 113.00
# 113.25
# 113.50
# 113.75
# 114.00
# 114.25
# 114.50
# 114.75
# 115.00
# 115.25
# 115.50
# 115.75
# 116.00
# 116.25
# 116.50
# 116.75
# 117.00
# 117.25
# 117.50
# 117.75
# 118.00
# 118.25
# 118.50
# 118.75
# 119.00
# 119.25
# 119.50
# 119.75
# 120.00
# 120.25
# 120.50
# 120.75
# 121.00
# 121.25
# 121.50
# 121.75
# 122.00
# 122.25
# 122.50
# 122.75
# 123.00
# 123.25
# 123.50
# 123.75
# 124.00
# 124.25
# 124.50
# 124.75
# 125.00
# 125.25
# 125.50
# 125.75
# 126.00
# 126.25
# 126.50
# 126.75
# 127.00
# 127.25
# ...
